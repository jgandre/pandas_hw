# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %load_ext lab_black
import os
import csv
import pandas as pd

# File to Load (Remember to Change These)
path = os.path.join("Resources/purchase_data.csv")

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(path)
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data["SN"].value_counts()
total = [len(purchase_data["SN"].value_counts())]
total
type(total)
df = pd.DataFrame(total, columns=["Total Players"])
df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
(len(purchase_data["Item ID"].value_counts()))
(purchase_data["Price"].mean())
(len(purchase_data["Purchase ID"].value_counts()))
(purchase_data["Price"].sum())

(purchase_data["Price"].mean())
avg_price = purchase_data["Price"].mean()
total_rev = purchase_data["Price"].sum()

# %%
summary = [
    {
        "Unique Item Count": len(purchase_data["Item ID"].value_counts()),
        "Average Price": "${:.2f}".format(avg_price),
        "Number of Purchases": len(purchase_data["Purchase ID"].value_counts()),
        "Total Revenue": "${:.2f}".format(total_rev),
    }
]
summary_df = pd.DataFrame(summary)
summary_df
# Out:
#    Unique Item Count Average Price  Number of Purchases Total Revenue
# 0                183         $3.05                  780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# need to get the unique Males and Females
u_males = purchase_data[purchase_data["Gender"] == "Male"]
mc = u_males["SN"].value_counts()

u_females = purchase_data[purchase_data["Gender"] == "Female"]
fc = u_females["SN"].value_counts()

u_unknown = purchase_data[purchase_data["Gender"] == "Other / Non-Disclosed"]
uc = u_unknown["SN"].value_counts()

male_count = len(mc)
female_count = len(fc)
unknown_count = len(uc)

total_count = male_count + female_count + unknown_count

male_percent = (male_count / total_count) * 100
female_percent = (female_count / total_count) * 100
unknown_percent = (unknown_count / total_count) * 100

form_male_percent = "{0:.2f}%".format(male_percent)
form_female_percent = "{0:.2f}%".format(female_percent)
form_unknown_percent = "{0:.2f}%".format(unknown_percent)

data = {
    "Total Count": [male_count, female_count, unknown_count],
    "Percentage of Players": [
        form_male_percent,
        form_female_percent,
        form_unknown_percent,
    ],
}

df = pd.DataFrame(data, index=["Male", "Female", "Other/Non-Disclosed"])
df
# Out:
#                      Total Count Percentage of Players
# Male                         484                84.03%
# Female                        81                14.06%
# Other/Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# puchase count
male_purch_count = len(purchase_data.loc[purchase_data["Gender"] == "Male"])
female_purch_count = len(purchase_data.loc[purchase_data["Gender"] == "Female"])
unknown_purch_count = len(
    purchase_data.loc[purchase_data["Gender"] == "Other / Non-Disclosed"]
)

# %%
# avg purchase price
m_avg_price = purchase_data[purchase_data["Gender"] == "Male"]["Price"].mean()

f_avg_price = purchase_data[purchase_data["Gender"] == "Female"]["Price"].mean()

u_avg_price = purchase_data[purchase_data["Gender"] == "Other / Non-Disclosed"][
    "Price"
].mean()

form_m_avg_price = "{0:.2f}".format(m_avg_price)
form_f_avg_price = "{0:.2f}".format(f_avg_price)
form_u_avg_price = "{0:.2f}".format(u_avg_price)

# %%
# Total Purchase Value by gender
m_total_price = purchase_data[purchase_data["Gender"] == "Male"]["Price"].sum()

f_total_price = purchase_data[purchase_data["Gender"] == "Female"]["Price"].sum()

u_total_price = purchase_data[purchase_data["Gender"] == "Other / Non-Disclosed"][
    "Price"
].sum()


form_m_total_price = "${:.2f}".format(m_total_price)
form_f_total_price = "${:.2f}".format(f_total_price)
form_u_total_price = "${:.2f}".format(u_total_price)

# %%
# avg total purchase per person by gender
m_total_price = purchase_data[purchase_data["Gender"] == "Male"]["Price"].sum()

f_total_price = purchase_data[purchase_data["Gender"] == "Female"]["Price"].sum()

u_total_price = purchase_data[purchase_data["Gender"] == "Other / Non-Disclosed"][
    "Price"
].sum()

m_avg_total = m_total_price / male_count
f_avg_total = f_total_price / female_count
u_avg_total = u_total_price / unknown_count

form_m_avg_total = "${:.2f}".format(m_avg_total)
form_f_avg_total = "${:.2f}".format(f_avg_total)
form_u_avg_total = "${:.2f}".format(u_avg_total)

# %%
# dataframe for Puchase Analysis(Gender)

data = {
    "Purchase Count": [male_purch_count, female_purch_count, unknown_purch_count],
    "Avg Purchase Price": [form_m_avg_price, form_f_avg_price, form_u_avg_price],
    "Total Purchase Value": [
        form_m_total_price,
        form_f_total_price,
        form_u_total_price,
    ],
    "Avg Total Puchases per Person": [
        form_m_avg_total,
        form_f_avg_total,
        form_u_avg_total,
    ],
}

df = pd.DataFrame(data, index=["Male", "Female", "Other/Non-Disclosed"])
df
# Out:
#                      Purchase Count Avg Purchase Price Total Purchase Value  \
# Male                            652               3.02             $1967.64
# Female                          113               3.20              $361.94
# Other/Non-Disclosed              15               3.35               $50.19
#
#                     Avg Total Puchases per Person
# Male                                        $4.07
# Female                                      $4.47
# Other/Non-Disclosed                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
df = purchase_data["Age"]
purchase_data["Age Ranges"] = pd.cut(
    x=df,
    bins=[0, 10, 15, 20, 25, 30, 35, 40, 100],
    right=False,
    labels=[
        "<10",
        "10 to 14",
        "15 to 19",
        "20 to 24",
        "25 to 29",
        "30 to 34",
        "35 to 39",
        "40+",
    ],
)

# %%
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Ranges
# 0    Extraction, Quickblade Of Trembling Hands   3.53   20 to 24
# 1                            Frenzied Scimitar   1.56        40+
# 2                                 Final Critic   4.88   20 to 24
# 3                                  Blindscythe   3.27   20 to 24
# 4                                         Fury   1.44   20 to 24
# ..                                         ...    ...        ...
# 775                                       Wolf   3.54   20 to 24
# 776                           Exiled Doomblade   1.63   20 to 24
# 777      Celeste, Incarnation of the Corrupted   3.46   20 to 24
# 778                               Final Critic   4.19        <10
# 779                                       Dawn   4.60   20 to 24
#
# [780 rows x 8 columns]

# %%
percentage = purchase_data["Age Ranges"].value_counts() / total
age_range_count = purchase_data["Age Ranges"].value_counts()

age_range = {
    "Age Range Counts": age_range_count,
    "Percentage of Age Groups": percentage,
}
age_range_df = pd.DataFrame(age_range)
age_range_df
# Out:
#           Age Range Counts  Percentage of Age Groups
# 20 to 24               365                  0.633681
# 15 to 19               136                  0.236111
# 25 to 29               101                  0.175347
# 30 to 34                73                  0.126736
# 35 t0 39                41                  0.071181
# 10 to 14                28                  0.048611
# <10                     23                  0.039931
# 40+                     13                  0.022569

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data["Price"]
# Out:
# 0      3.53
# 1      1.56
# 2      4.88
# 3      3.27
# 4      1.44
#        ...
# 775    3.54
# 776    1.63
# 777    3.46
# 778    4.19
# 779    4.60
# Name: Price, Length: 780, dtype: float64

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_data["SN"].value_counts().head(5)

# %%
df = purchase_data.loc[purchase_data["SN"] == "Lisosia93"]
df_count = df["SN"].value_counts()


df_avg = df["Price"].mean()
form_df_avg = "${:.2f}".format(df_avg)
form_df_avg

df_total_price = df["Price"].sum()
form_df_total = "${:.2f}".format(df_total_price)


sn_two = purchase_data.loc[purchase_data["SN"] == "Idastidru52"]
sn_two_count = sn_two["SN"].value_counts()
sn_two_avg = sn_two["Price"].mean()
form_sn_two_avg = "${:.2f}".format(sn_two_avg)
form_sn_two_avg

sn_two_total_price = sn_two["Price"].sum()
form_sn_two_total = "${:.2f}".format(sn_two_total_price)

sn_three = purchase_data.loc[purchase_data["SN"] == "Chamjask73"]
sn_three_count = sn_three["SN"].value_counts()
sn_three_avg = sn_three["Price"].mean()
form_sn_three_avg = "${:.2f}".format(sn_three_avg)
form_sn_three_avg

sn_three_total_price = sn_three["Price"].sum()
form_sn_three_total = "${:.2f}".format(sn_three_total_price)

sn_four = purchase_data.loc[purchase_data["SN"] == "Iral74"]
sn_four_count = sn_four["SN"].value_counts()
sn_four_avg = sn_four["Price"].mean()
form_sn_four_avg = "${:.2f}".format(sn_four_avg)
form_sn_four_avg

sn_four_total_price = sn_four["Price"].sum()
form_sn_four_total = "${:.2f}".format(sn_four_total_price)

sn_five = purchase_data.loc[purchase_data["SN"] == "Iskadarya95"]
sn_five_count = sn_five["SN"].value_counts()
sn_five_avg = sn_five["Price"].mean()
form_sn_five_avg = "${:.2f}".format(sn_five_avg)
form_sn_five_avg

sn_five_total_price = sn_five["Price"].sum()
form_sn_five_total = "${:.2f}".format(sn_five_total_price)


data = {
    "Purchase Count": [5, 4, 3, 4, 3,],
    "Avg Purchase Price": [
        form_df_avg,
        form_sn_two_avg,
        form_sn_three_avg,
        form_sn_four_avg,
        form_sn_five_avg,
    ],
    "Total Purchase Value": [
        form_df_total,
        form_sn_two_total,
        form_sn_three_total,
        form_sn_four_total,
        form_sn_five_total,
    ],
}

new_df = pd.DataFrame(
    data, index=["Lisosia93", "Idastidru52", "Chamjask73", "Iral74", "Iskadarya95"]
)
new_df

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items_df = purchase_data[["Price", "Item Name", "Item ID"]]
items_df
# Out:
#      Price                                  Item Name  Item ID
# 0     3.53  Extraction, Quickblade Of Trembling Hands      108
# 1     1.56                          Frenzied Scimitar      143
# 2     4.88                               Final Critic       92
# 3     3.27                                Blindscythe      100
# 4     1.44                                       Fury      131
# ..     ...                                        ...      ...
# 775   3.54                                       Wolf       60
# 776   1.63                           Exiled Doomblade      164
# 777   3.46      Celeste, Incarnation of the Corrupted       67
# 778   4.19                               Final Critic      101
# 779   4.60                                       Dawn       50
#
# [780 rows x 3 columns]

# %%
items_gb = items_df.groupby(["Item ID", "Item Name"])
for name, df in items_gb:
    print(f"Name: {name}")
    print(df)
# Out:
# Name: (0, 'Splinter')
#      Price Item Name  Item ID
# 133   1.28  Splinter        0
# 150   1.28  Splinter        0
# 204   1.28  Splinter        0
# 662   1.28  Splinter        0
# Name: (1, 'Crucifer')
#      Price Item Name  Item ID
# 121   3.26  Crucifer        1
# 454   3.26  Crucifer        1
# 697   3.26  Crucifer        1
# Name: (2, 'Verdict')
#      Price Item Name  Item ID
# 134   2.48   Verdict        2
# 201   2.48   Verdict        2
# 213   2.48   Verdict        2
# 345   2.48   Verdict        2
# 553   2.48   Verdict        2
# 560   2.48   Verdict        2
# Name: (3, 'Phantomlight')
#      Price     Item Name  Item ID
# 161   2.49  Phantomlight        3
# 203   2.49  Phantomlight        3
# 317   2.49  Phantomlight        3
# 368   2.49  Phantomlight        3
# 494   2.49  Phantomlight        3
# 544   2.49  Phantomlight        3
# Name: (4, "Bloodlord's Fetish")
#      Price           Item Name  Item ID
# 13     1.7  Bloodlord's Fetish        4
# 302    1.7  Bloodlord's Fetish        4
# 465    1.7  Bloodlord's Fetish        4
# 470    1.7  Bloodlord's Fetish        4
# 635    1.7  Bloodlord's Fetish        4
# Name: (5, 'Putrid Fan')
#      Price   Item Name  Item ID
# 173   4.08  Putrid Fan        5
# 287   4.08  Putrid Fan        5
# 530   4.08  Putrid Fan        5
# 742   4.08  Putrid Fan        5
# Name: (6, 'Rusty Skull')
#      Price    Item Name  Item ID
# 66     3.7  Rusty Skull        6
# 475    3.7  Rusty Skull        6
# Name: (7, 'Thorn, Satchel of Dark Souls')
#      Price                     Item Name  Item ID
# 41    1.33  Thorn, Satchel of Dark Souls        7
# 103   1.33  Thorn, Satchel of Dark Souls        7
# 112   1.33  Thorn, Satchel of Dark Souls        7
# 331   1.33  Thorn, Satchel of Dark Souls        7
# 508   1.33  Thorn, Satchel of Dark Souls        7
# 540   1.33  Thorn, Satchel of Dark Souls        7
# 555   1.33  Thorn, Satchel of Dark Souls        7
# Name: (8, 'Purgatory, Gem of Regret')
#      Price                 Item Name  Item ID
# 140   3.93  Purgatory, Gem of Regret        8
# 557   3.93  Purgatory, Gem of Regret        8
# 715   3.93  Purgatory, Gem of Regret        8
# Name: (9, 'Thorn, Conqueror of the Corrupted')
#      Price                          Item Name  Item ID
# 44    2.73  Thorn, Conqueror of the Corrupted        9
# 196   2.73  Thorn, Conqueror of the Corrupted        9
# 276   2.73  Thorn, Conqueror of the Corrupted        9
# 283   2.73  Thorn, Conqueror of the Corrupted        9
# Name: (10, 'Sleepwalker')
#      Price    Item Name  Item ID
# 105   1.79  Sleepwalker       10
# 241   1.79  Sleepwalker       10
# 423   1.79  Sleepwalker       10
# 701   1.79  Sleepwalker       10
# Name: (11, 'Brimstone')
#      Price  Item Name  Item ID
# 187   3.65  Brimstone       11
# 334   3.65  Brimstone       11
# 347   3.65  Brimstone       11
# 377   3.65  Brimstone       11
# 383   3.65  Brimstone       11
# Name: (12, 'Dawne')
#      Price Item Name  Item ID
# 83    1.02     Dawne       12
# 100   1.02     Dawne       12
# 579   1.02     Dawne       12
# 702   1.02     Dawne       12
# 731   1.02     Dawne       12
# 770   1.02     Dawne       12
# Name: (13, 'Serenity')
#      Price Item Name  Item ID
# 115   1.41  Serenity       13
# 338   1.41  Serenity       13
# 416   1.41  Serenity       13
# 599   1.41  Serenity       13
# Name: (14, 'Possessed Core')
#      Price       Item Name  Item ID
# 360   2.61  Possessed Core       14
# 428   2.61  Possessed Core       14
# Name: (15, 'Soul Infused Crystal')
#      Price             Item Name  Item ID
# 51    2.96  Soul Infused Crystal       15
# 79    2.96  Soul Infused Crystal       15
# 183   2.96  Soul Infused Crystal       15
# 316   2.96  Soul Infused Crystal       15
# 588   2.96  Soul Infused Crystal       15
# Name: (16, 'Restored Bauble')
#      Price        Item Name  Item ID
# 237   3.55  Restored Bauble       16
# 249   3.55  Restored Bauble       16
# 280   3.55  Restored Bauble       16
# 502   3.55  Restored Bauble       16
# Name: (17, 'Lazarus, Terror of the Earth')
#      Price                     Item Name  Item ID
# 89     1.7  Lazarus, Terror of the Earth       17
# 327    1.7  Lazarus, Terror of the Earth       17
# 337    1.7  Lazarus, Terror of the Earth       17
# 761    1.7  Lazarus, Terror of the Earth       17
# Name: (18, 'Torchlight, Bond of Storms')
#      Price                   Item Name  Item ID
# 269   4.65  Torchlight, Bond of Storms       18
# 472   4.65  Torchlight, Bond of Storms       18
# Name: (19, 'Pursuit, Cudgel of Necromancy')
#      Price                      Item Name  Item ID
# 239   1.02  Pursuit, Cudgel of Necromancy       19
# 344   1.02  Pursuit, Cudgel of Necromancy       19
# 361   1.02  Pursuit, Cudgel of Necromancy       19
# 528   1.02  Pursuit, Cudgel of Necromancy       19
# 582   1.02  Pursuit, Cudgel of Necromancy       19
# 654   1.02  Pursuit, Cudgel of Necromancy       19
# 657   1.02  Pursuit, Cudgel of Necromancy       19
# 773   1.02  Pursuit, Cudgel of Necromancy       19
# Name: (20, 'Netherbane')
#      Price   Item Name  Item ID
# 77    3.27  Netherbane       20
# 391   3.27  Netherbane       20
# 425   3.27  Netherbane       20
# 655   3.27  Netherbane       20
# 718   3.27  Netherbane       20
# Name: (21, 'Souleater')
#      Price  Item Name  Item ID
# 8      1.1  Souleater       21
# 514    1.1  Souleater       21
# 523    1.1  Souleater       21
# 532    1.1  Souleater       21
# 726    1.1  Souleater       21
# Name: (22, 'Amnesia')
#      Price Item Name  Item ID
# 50    2.18   Amnesia       22
# 144   2.18   Amnesia       22
# 491   2.18   Amnesia       22
# 542   2.18   Amnesia       22
# 638   2.18   Amnesia       22
# 644   2.18   Amnesia       22
# Name: (23, 'Crucifer')
#      Price Item Name  Item ID
# 251   1.99  Crucifer       23
# Name: (24, 'Warped Fetish')
#      Price      Item Name  Item ID
# 22    3.81  Warped Fetish       24
# 120   3.81  Warped Fetish       24
# 147   3.81  Warped Fetish       24
# 227   3.81  Warped Fetish       24
# 444   3.81  Warped Fetish       24
# Name: (25, 'Hero Cane')
#      Price  Item Name  Item ID
# 54    4.35  Hero Cane       25
# 217   4.35  Hero Cane       25
# 473   4.35  Hero Cane       25
# 506   4.35  Hero Cane       25
# 513   4.35  Hero Cane       25
# 771   4.35  Hero Cane       25
# Name: (26, 'Unholy Wand')
#      Price    Item Name  Item ID
# 421   1.12  Unholy Wand       26
# 621   1.12  Unholy Wand       26
# Name: (27, 'Riddle, Tribute of Ended Dreams')
#     Price                        Item Name  Item ID
# 68    3.3  Riddle, Tribute of Ended Dreams       27
# Name: (28, 'Flux, Destroyer of Due Diligence')
#      Price                         Item Name  Item ID
# 253   1.06  Flux, Destroyer of Due Diligence       28
# 681   1.06  Flux, Destroyer of Due Diligence       28
# Name: (29, 'Chaos, Ender of the End')
#      Price                Item Name  Item ID
# 71    1.98  Chaos, Ender of the End       29
# 385   1.98  Chaos, Ender of the End       29
# 507   1.98  Chaos, Ender of the End       29
# 624   1.98  Chaos, Ender of the End       29
# 688   1.98  Chaos, Ender of the End       29
# Name: (30, 'Stormcaller')
#      Price    Item Name  Item ID
# 166   2.21  Stormcaller       30
# 468   2.21  Stormcaller       30
# Name: (31, 'Trickster')
#      Price  Item Name  Item ID
# 366   1.55  Trickster       31
# 566   1.55  Trickster       31
# Name: (32, 'Orenmir')
#      Price Item Name  Item ID
# 184   1.14   Orenmir       32
# 426   1.14   Orenmir       32
# 452   1.14   Orenmir       32
# 489   1.14   Orenmir       32
# 677   1.14   Orenmir       32
# Name: (33, 'Curved Axe')
#      Price   Item Name  Item ID
# 85    1.16  Curved Axe       33
# 109   1.16  Curved Axe       33
# Name: (34, 'Retribution Axe')
#      Price        Item Name  Item ID
# 65    2.22  Retribution Axe       34
# 84    2.22  Retribution Axe       34
# 350   2.22  Retribution Axe       34
# 449   2.22  Retribution Axe       34
# 559   2.22  Retribution Axe       34
# 576   2.22  Retribution Axe       34
# 604   2.22  Retribution Axe       34
# 685   2.22  Retribution Axe       34
# Name: (35, 'Heartless Bone Dualblade')
#      Price                 Item Name  Item ID
# 291   3.45  Heartless Bone Dualblade       35
# 450   3.45  Heartless Bone Dualblade       35
# 478   3.45  Heartless Bone Dualblade       35
# 516   3.45  Heartless Bone Dualblade       35
# 561   3.45  Heartless Bone Dualblade       35
# Name: (37, 'Shadow Strike, Glory of Ending Hope')
#      Price                            Item Name  Item ID
# 29    3.16  Shadow Strike, Glory of Ending Hope       37
# 69    3.16  Shadow Strike, Glory of Ending Hope       37
# 197   3.16  Shadow Strike, Glory of Ending Hope       37
# 244   3.16  Shadow Strike, Glory of Ending Hope       37
# 314   3.16  Shadow Strike, Glory of Ending Hope       37
# 322   3.16  Shadow Strike, Glory of Ending Hope       37
# 357   3.16  Shadow Strike, Glory of Ending Hope       37
# 745   3.16  Shadow Strike, Glory of Ending Hope       37
# Name: (38, 'The Void, Vengeance of Dark Magic')
#      Price                          Item Name  Item ID
# 306   2.37  The Void, Vengeance of Dark Magic       38
# 342   2.37  The Void, Vengeance of Dark Magic       38
# 348   2.37  The Void, Vengeance of Dark Magic       38
# 707   2.37  The Void, Vengeance of Dark Magic       38
# Name: (39, 'Betrayal, Whisper of Grieving Widows')
#      Price                             Item Name  Item ID
# 92    3.94  Betrayal, Whisper of Grieving Widows       39
# 159   3.94  Betrayal, Whisper of Grieving Widows       39
# 242   3.94  Betrayal, Whisper of Grieving Widows       39
# 387   3.94  Betrayal, Whisper of Grieving Widows       39
# 484   3.94  Betrayal, Whisper of Grieving Widows       39
# Name: (40, 'Second Chance')
#      Price      Item Name  Item ID
# 16    2.52  Second Chance       40
# 215   2.52  Second Chance       40
# 515   2.52  Second Chance       40
# 609   2.52  Second Chance       40
# 617   2.52  Second Chance       40
# 668   2.52  Second Chance       40
# Name: (41, 'Orbit')
#      Price Item Name  Item ID
# 111   4.75     Orbit       41
# 267   4.75     Orbit       41
# 340   4.75     Orbit       41
# Name: (42, 'The Decapitator')
#      Price        Item Name  Item ID
# 238   1.75  The Decapitator       42
# Name: (43, 'Foul Edge')
#      Price  Item Name  Item ID
# 365   3.54  Foul Edge       43
# 437   3.54  Foul Edge       43
# Name: (44, 'Bonecarvin Battle Axe')
#      Price              Item Name  Item ID
# 33    2.38  Bonecarvin Battle Axe       44
# 60    2.38  Bonecarvin Battle Axe       44
# 160   2.38  Bonecarvin Battle Axe       44
# 488   2.38  Bonecarvin Battle Axe       44
# 760   2.38  Bonecarvin Battle Axe       44
# Name: (45, 'Glinting Glass Edge')
#      Price            Item Name  Item ID
# 336   3.85  Glinting Glass Edge       45
# 363   3.85  Glinting Glass Edge       45
# 370   3.85  Glinting Glass Edge       45
# 669   3.85  Glinting Glass Edge       45
# Name: (46, 'Hopeless Ebon Dualblade')
#      Price                Item Name  Item ID
# 145   1.33  Hopeless Ebon Dualblade       46
# 220   1.33  Hopeless Ebon Dualblade       46
# 401   1.33  Hopeless Ebon Dualblade       46
# 524   1.33  Hopeless Ebon Dualblade       46
# 713   1.33  Hopeless Ebon Dualblade       46
# Name: (47, 'Alpha, Reach of Ending Hope')
#      Price                    Item Name  Item ID
# 664   3.58  Alpha, Reach of Ending Hope       47
# Name: (48, 'Rage, Legacy of the Lone Victor')
#      Price                        Item Name  Item ID
# 463   2.48  Rage, Legacy of the Lone Victor       48
# 533   2.48  Rage, Legacy of the Lone Victor       48
# Name: (49, 'The Oculus, Token of Lost Worlds')
#      Price                         Item Name  Item ID
# 343   2.96  The Oculus, Token of Lost Worlds       49
# 583   2.96  The Oculus, Token of Lost Worlds       49
# 641   2.96  The Oculus, Token of Lost Worlds       49
# Name: (50, 'Dawn')
#      Price Item Name  Item ID
# 78     4.6      Dawn       50
# 380    4.6      Dawn       50
# 521    4.6      Dawn       50
# 779    4.6      Dawn       50
# Name: (51, 'Endbringer')
#      Price   Item Name  Item ID
# 181   4.66  Endbringer       51
# Name: (52, 'Hatred')
#      Price Item Name  Item ID
# 295   4.84    Hatred       52
# 497   4.84    Hatred       52
# 564   4.84    Hatred       52
# 612   4.84    Hatred       52
# Name: (53, 'Vengeance Cleaver')
#      Price          Item Name  Item ID
# 35    2.05  Vengeance Cleaver       53
# 104   2.05  Vengeance Cleaver       53
# 307   2.05  Vengeance Cleaver       53
# 408   2.05  Vengeance Cleaver       53
# 486   2.05  Vengeance Cleaver       53
# 653   2.05  Vengeance Cleaver       53
# 749   2.05  Vengeance Cleaver       53
# Name: (54, 'Eternal Cleaver')
#      Price        Item Name  Item ID
# 106    2.5  Eternal Cleaver       54
# 226    2.5  Eternal Cleaver       54
# 325    2.5  Eternal Cleaver       54
# 326    2.5  Eternal Cleaver       54
# 393    2.5  Eternal Cleaver       54
# 735    2.5  Eternal Cleaver       54
# Name: (55, 'Vindictive Glass Edge')
#      Price              Item Name  Item ID
# 595   2.27  Vindictive Glass Edge       55
# 619   2.27  Vindictive Glass Edge       55
# 748   2.27  Vindictive Glass Edge       55
# Name: (56, 'Foul Titanium Battle Axe')
#     Price                 Item Name  Item ID
# 64   2.92  Foul Titanium Battle Axe       56
# 96   2.92  Foul Titanium Battle Axe       56
# Name: (57, 'Despair, Favor of Due Diligence')
#      Price                        Item Name  Item ID
# 20     4.6  Despair, Favor of Due Diligence       57
# 178    4.6  Despair, Favor of Due Diligence       57
# 219    4.6  Despair, Favor of Due Diligence       57
# 757    4.6  Despair, Favor of Due Diligence       57
# Name: (58, "Freak's Bite, Favor of Holy Might")
#      Price                          Item Name  Item ID
# 128   4.14  Freak's Bite, Favor of Holy Might       58
# 698   4.14  Freak's Bite, Favor of Holy Might       58
# 736   4.14  Freak's Bite, Favor of Holy Might       58
# 766   4.14  Freak's Bite, Favor of Holy Might       58
# Name: (59, 'Lightning, Etcher of the King')
#      Price                      Item Name  Item ID
# 91    4.23  Lightning, Etcher of the King       59
# 154   4.23  Lightning, Etcher of the King       59
# 179   4.23  Lightning, Etcher of the King       59
# 349   4.23  Lightning, Etcher of the King       59
# 376   4.23  Lightning, Etcher of the King       59
# 439   4.23  Lightning, Etcher of the King       59
# 480   4.23  Lightning, Etcher of the King       59
# 503   4.23  Lightning, Etcher of the King       59
# Name: (60, 'Wolf')
#      Price Item Name  Item ID
# 52    3.54      Wolf       60
# 90    3.54      Wolf       60
# 141   3.54      Wolf       60
# 394   3.54      Wolf       60
# 479   3.54      Wolf       60
# 550   3.54      Wolf       60
# 661   3.54      Wolf       60
# 775   3.54      Wolf       60
# Name: (61, 'Ragnarok')
#      Price Item Name  Item ID
# 457   3.87  Ragnarok       61
# 647   3.87  Ragnarok       61
# 739   3.87  Ragnarok       61
# Name: (62, 'Piece Maker')
#      Price    Item Name  Item ID
# 125   1.87  Piece Maker       62
# 131   1.87  Piece Maker       62
# 193   1.87  Piece Maker       62
# Name: (63, 'Stormfury Mace')
#      Price       Item Name  Item ID
# 189   4.99  Stormfury Mace       63
# 554   4.99  Stormfury Mace       63
# Name: (64, 'Fusion Pummel')
#      Price      Item Name  Item ID
# 372   4.82  Fusion Pummel       64
# 511   4.82  Fusion Pummel       64
# 556   4.82  Fusion Pummel       64
# Name: (65, 'Conqueror Adamantite Mace')
#      Price                  Item Name  Item ID
# 163   4.24  Conqueror Adamantite Mace       65
# 172   4.24  Conqueror Adamantite Mace       65
# 296   4.24  Conqueror Adamantite Mace       65
# 602   4.24  Conqueror Adamantite Mace       65
# 614   4.24  Conqueror Adamantite Mace       65
# Name: (66, 'Victor Iron Spikes')
#      Price           Item Name  Item ID
# 233    4.4  Victor Iron Spikes       66
# 545    4.4  Victor Iron Spikes       66
# 667    4.4  Victor Iron Spikes       66
# 733    4.4  Victor Iron Spikes       66
# Name: (67, 'Celeste, Incarnation of the Corrupted')
#      Price                              Item Name  Item ID
# 335   3.46  Celeste, Incarnation of the Corrupted       67
# 649   3.46  Celeste, Incarnation of the Corrupted       67
# 708   3.46  Celeste, Incarnation of the Corrupted       67
# 777   3.46  Celeste, Incarnation of the Corrupted       67
# Name: (68, 'Storm-Weaver, Slayer of Inception')
#      Price                          Item Name  Item ID
# 73    4.32  Storm-Weaver, Slayer of Inception       68
# 281   4.32  Storm-Weaver, Slayer of Inception       68
# 448   4.32  Storm-Weaver, Slayer of Inception       68
# 690   4.32  Storm-Weaver, Slayer of Inception       68
# Name: (69, 'Frenzy, Defender of the Harvest')
#      Price                        Item Name  Item ID
# 190   1.98  Frenzy, Defender of the Harvest       69
# 570   1.98  Frenzy, Defender of the Harvest       69
# Name: (70, "Hope's End")
#      Price   Item Name  Item ID
# 260   1.03  Hope's End       70
# 292   1.03  Hope's End       70
# 405   1.03  Hope's End       70
# 453   1.03  Hope's End       70
# Name: (71, 'Demise')
#      Price Item Name  Item ID
# 26    1.61    Demise       71
# 255   1.61    Demise       71
# 268   1.61    Demise       71
# 303   1.61    Demise       71
# 311   1.61    Demise       71
# 341   1.61    Demise       71
# 404   1.61    Demise       71
# Name: (72, "Winter's Bite")
#      Price      Item Name  Item ID
# 42    3.77  Winter's Bite       72
# 229   3.77  Winter's Bite       72
# 259   3.77  Winter's Bite       72
# 400   3.77  Winter's Bite       72
# 615   3.77  Winter's Bite       72
# 663   3.77  Winter's Bite       72
# 725   3.77  Winter's Bite       72
# 759   3.77  Winter's Bite       72
# Name: (73, 'Ritual Mace')
#      Price    Item Name  Item ID
# 37    2.05  Ritual Mace       73
# 194   2.05  Ritual Mace       73
# 359   2.05  Ritual Mace       73
# 665   2.05  Ritual Mace       73
# 756   2.05  Ritual Mace       73
# Name: (74, 'Yearning Crusher')
#      Price         Item Name  Item ID
# 129   4.18  Yearning Crusher       74
# 358   4.18  Yearning Crusher       74
# 729   4.18  Yearning Crusher       74
# Name: (75, 'Brutality Ivory Warmace')
#      Price                Item Name  Item ID
# 126   2.42  Brutality Ivory Warmace       75
# 170   2.42  Brutality Ivory Warmace       75
# 390   2.42  Brutality Ivory Warmace       75
# 440   2.42  Brutality Ivory Warmace       75
# 548   2.42  Brutality Ivory Warmace       75
# 626   2.42  Brutality Ivory Warmace       75
# 652   2.42  Brutality Ivory Warmace       75
# 709   2.42  Brutality Ivory Warmace       75
# Name: (76, 'Haunted Bronzed Bludgeon')
#      Price                 Item Name  Item ID
# 36    3.15  Haunted Bronzed Bludgeon       76
# 218   3.15  Haunted Bronzed Bludgeon       76
# 689   3.15  Haunted Bronzed Bludgeon       76
# 755   3.15  Haunted Bronzed Bludgeon       76
# Name: (77, 'Piety, Guardian of Riddles')
#      Price                   Item Name  Item ID
# 186    4.0  Piety, Guardian of Riddles       77
# 320    4.0  Piety, Guardian of Riddles       77
# 482    4.0  Piety, Guardian of Riddles       77
# 674    4.0  Piety, Guardian of Riddles       77
# Name: (78, 'Glimmer, Ender of the Moon')
#      Price                   Item Name  Item ID
# 118    4.4  Glimmer, Ender of the Moon       78
# 206    4.4  Glimmer, Ender of the Moon       78
# 263    4.4  Glimmer, Ender of the Moon       78
# 616    4.4  Glimmer, Ender of the Moon       78
# 636    4.4  Glimmer, Ender of the Moon       78
# 687    4.4  Glimmer, Ender of the Moon       78
# 692    4.4  Glimmer, Ender of the Moon       78
# Name: (79, 'Alpha, Oath of Zeal')
#      Price            Item Name  Item ID
# 352   4.05  Alpha, Oath of Zeal       79
# 496   4.05  Alpha, Oath of Zeal       79
# 754   4.05  Alpha, Oath of Zeal       79
# Name: (80, 'Dreamsong')
#      Price  Item Name  Item ID
# 57    3.39  Dreamsong       80
# 228   3.39  Dreamsong       80
# 436   3.39  Dreamsong       80
# 607   3.39  Dreamsong       80
# 633   3.39  Dreamsong       80
# Name: (81, 'Dreamkiss')
#      Price  Item Name  Item ID
# 5     3.61  Dreamkiss       81
# 123   3.61  Dreamkiss       81
# Name: (82, 'Nirvana')
#      Price Item Name  Item ID
# 18     4.9   Nirvana       82
# 88     4.9   Nirvana       82
# 202    4.9   Nirvana       82
# 240    4.9   Nirvana       82
# 247    4.9   Nirvana       82
# 274    4.9   Nirvana       82
# 504    4.9   Nirvana       82
# 522    4.9   Nirvana       82
# 666    4.9   Nirvana       82
# Name: (83, 'Lifebender')
#      Price   Item Name  Item ID
# 243   3.33  Lifebender       83
# 289   3.33  Lifebender       83
# 381   3.33  Lifebender       83
# 562   3.33  Lifebender       83
# Name: (84, 'Arcane Gem')
#      Price   Item Name  Item ID
# 55    3.79  Arcane Gem       84
# 434   3.79  Arcane Gem       84
# 442   3.79  Arcane Gem       84
# Name: (85, 'Malificent Bag')
#      Price       Item Name  Item ID
# 108   1.75  Malificent Bag       85
# 168   1.75  Malificent Bag       85
# 245   1.75  Malificent Bag       85
# 270   1.75  Malificent Bag       85
# 374   1.75  Malificent Bag       85
# 585   1.75  Malificent Bag       85
# 763   1.75  Malificent Bag       85
# Name: (86, 'Stormfury Lantern')
#      Price          Item Name  Item ID
# 412   2.27  Stormfury Lantern       86
# 597   2.27  Stormfury Lantern       86
# 639   2.27  Stormfury Lantern       86
# Name: (87, 'Deluge, Edge of the West')
#      Price                 Item Name  Item ID
# 119   4.43  Deluge, Edge of the West       87
# 191   4.43  Deluge, Edge of the West       87
# 250   4.43  Deluge, Edge of the West       87
# 569   4.43  Deluge, Edge of the West       87
# 696   4.43  Deluge, Edge of the West       87
# Name: (88, 'Emberling, Defender of Delusions')
#      Price                         Item Name  Item ID
# 76    3.75  Emberling, Defender of Delusions       88
# 93    3.75  Emberling, Defender of Delusions       88
# 188   3.75  Emberling, Defender of Delusions       88
# 364   3.75  Emberling, Defender of Delusions       88
# 693   3.75  Emberling, Defender of Delusions       88
# Name: (89, 'Blazefury, Protector of Delusions')
#      Price                          Item Name  Item ID
# 19    4.64  Blazefury, Protector of Delusions       89
# 74    4.64  Blazefury, Protector of Delusions       89
# 594   4.64  Blazefury, Protector of Delusions       89
# Name: (90, 'Betrayer')
#      Price Item Name  Item ID
# 700   2.94  Betrayer       90
# Name: (91, 'Celeste')
#      Price Item Name  Item ID
# 318   4.17   Celeste       91
# Name: (92, 'Final Critic')
#      Price     Item Name  Item ID
# 2     4.88  Final Critic       92
# 252   4.88  Final Critic       92
# 273   4.88  Final Critic       92
# 277   4.88  Final Critic       92
# 712   4.88  Final Critic       92
# 722   4.88  Final Critic       92
# 767   4.88  Final Critic       92
# 768   4.88  Final Critic       92
# Name: (93, 'Apocalyptic Battlescythe')
#      Price                 Item Name  Item ID
# 413   1.97  Apocalyptic Battlescythe       93
# 435   1.97  Apocalyptic Battlescythe       93
# 487   1.97  Apocalyptic Battlescythe       93
# 601   1.97  Apocalyptic Battlescythe       93
# 643   1.97  Apocalyptic Battlescythe       93
# 728   1.97  Apocalyptic Battlescythe       93
# Name: (94, 'Mourning Blade')
#      Price       Item Name  Item ID
# 254   3.49  Mourning Blade       94
# 485   3.49  Mourning Blade       94
# 711   3.49  Mourning Blade       94
# 744   3.49  Mourning Blade       94
# Name: (95, 'Singed Onyx Warscythe')
#      Price              Item Name  Item ID
# 10    4.74  Singed Onyx Warscythe       95
# 180   4.74  Singed Onyx Warscythe       95
# 704   4.74  Singed Onyx Warscythe       95
# Name: (96, 'Blood-Forged Skeletal Spine')
#      Price                    Item Name  Item ID
# 27    3.09  Blood-Forged Skeletal Spine       96
# 94    3.09  Blood-Forged Skeletal Spine       96
# 164   3.09  Blood-Forged Skeletal Spine       96
# 378   3.09  Blood-Forged Skeletal Spine       96
# 398   3.09  Blood-Forged Skeletal Spine       96
# 680   3.09  Blood-Forged Skeletal Spine       96
# Name: (97, 'Swan Song, Gouger Of Terror')
#      Price                    Item Name  Item ID
# 234    2.5  Swan Song, Gouger Of Terror       97
# 495    2.5  Swan Song, Gouger Of Terror       97
# 732    2.5  Swan Song, Gouger Of Terror       97
# Name: (98, 'Deadline, Voice Of Subtlety')
#      Price                    Item Name  Item ID
# 15    2.89  Deadline, Voice Of Subtlety       98
# 155   2.89  Deadline, Voice Of Subtlety       98
# 192   2.89  Deadline, Voice Of Subtlety       98
# 308   2.89  Deadline, Voice Of Subtlety       98
# 417   2.89  Deadline, Voice Of Subtlety       98
# Name: (99, 'Expiration, Warscythe Of Lost Worlds')
#      Price                             Item Name  Item ID
# 107   1.71  Expiration, Warscythe Of Lost Worlds       99
# 410   1.71  Expiration, Warscythe Of Lost Worlds       99
# 499   1.71  Expiration, Warscythe Of Lost Worlds       99
# 710   1.71  Expiration, Warscythe Of Lost Worlds       99
# Name: (100, 'Blindscythe')
#      Price    Item Name  Item ID
# 3     3.27  Blindscythe      100
# 379   3.27  Blindscythe      100
# 397   3.27  Blindscythe      100
# 406   3.27  Blindscythe      100
# 500   3.27  Blindscythe      100
# Name: (101, 'Final Critic')
#      Price     Item Name  Item ID
# 99    4.19  Final Critic      101
# 411   4.19  Final Critic      101
# 536   4.19  Final Critic      101
# 774   4.19  Final Critic      101
# 778   4.19  Final Critic      101
# Name: (102, 'Avenger')
#      Price Item Name  Item ID
# 46    3.44   Avenger      102
# 127   3.44   Avenger      102
# 171   3.44   Avenger      102
# 230   3.44   Avenger      102
# 527   3.44   Avenger      102
# 567   3.44   Avenger      102
# Name: (103, 'Singed Scalpel')
#      Price       Item Name  Item ID
# 175   4.35  Singed Scalpel      103
# 373   4.35  Singed Scalpel      103
# 455   4.35  Singed Scalpel      103
# 460   4.35  Singed Scalpel      103
# 476   4.35  Singed Scalpel      103
# 634   4.35  Singed Scalpel      103
# 660   4.35  Singed Scalpel      103
# 714   4.35  Singed Scalpel      103
# Name: (104, "Gladiator's Glaive")
#      Price           Item Name  Item ID
# 727   1.93  Gladiator's Glaive      104
# Name: (105, 'Hailstorm Shadowsteel Scythe')
#      Price                     Item Name  Item ID
# 59    3.03  Hailstorm Shadowsteel Scythe      105
# 136   3.03  Hailstorm Shadowsteel Scythe      105
# 151   3.03  Hailstorm Shadowsteel Scythe      105
# 208   3.03  Hailstorm Shadowsteel Scythe      105
# Name: (106, 'Crying Steel Sickle')
#      Price            Item Name  Item ID
# 301   3.41  Crying Steel Sickle      106
# 589   3.41  Crying Steel Sickle      106
# 716   3.41  Crying Steel Sickle      106
# Name: (107, 'Splitter, Foe Of Subtlety')
#      Price                  Item Name  Item ID
# 236   2.18  Splitter, Foe Of Subtlety      107
# 315   2.18  Splitter, Foe Of Subtlety      107
# 362   2.18  Splitter, Foe Of Subtlety      107
# 629   2.18  Splitter, Foe Of Subtlety      107
# Name: (108, 'Extraction, Quickblade Of Trembling Hands')
#      Price                                  Item Name  Item ID
# 0     3.53  Extraction, Quickblade Of Trembling Hands      108
# 56    3.53  Extraction, Quickblade Of Trembling Hands      108
# 157   3.53  Extraction, Quickblade Of Trembling Hands      108
# 414   3.53  Extraction, Quickblade Of Trembling Hands      108
# 483   3.53  Extraction, Quickblade Of Trembling Hands      108
# 498   3.53  Extraction, Quickblade Of Trembling Hands      108
# 558   3.53  Extraction, Quickblade Of Trembling Hands      108
# 640   3.53  Extraction, Quickblade Of Trembling Hands      108
# 678   3.53  Extraction, Quickblade Of Trembling Hands      108
# Name: (109, 'Downfall, Scalpel Of The Emperor')
#      Price                         Item Name  Item ID
# 102   4.76  Downfall, Scalpel Of The Emperor      109
# 520   4.76  Downfall, Scalpel Of The Emperor      109
# 620   4.76  Downfall, Scalpel Of The Emperor      109
# Name: (110, 'Suspension')
#      Price   Item Name  Item ID
# 49    1.44  Suspension      110
# 152   1.44  Suspension      110
# 298   1.44  Suspension      110
# 384   1.44  Suspension      110
# 505   1.44  Suspension      110
# 743   1.44  Suspension      110
# 762   1.44  Suspension      110
# Name: (111, "Misery's End")
#      Price     Item Name  Item ID
# 158   4.89  Misery's End      111
# 598   4.89  Misery's End      111
# 676   4.89  Misery's End      111
# 695   4.89  Misery's End      111
# Name: (112, 'Worldbreaker')
#      Price     Item Name  Item ID
# 466    2.6  Worldbreaker      112
# 537    2.6  Worldbreaker      112
# 691    2.6  Worldbreaker      112
# 752    2.6  Worldbreaker      112
# Name: (113, "Solitude's Reaver")
#      Price          Item Name  Item ID
# 195   4.07  Solitude's Reaver      113
# 266   4.07  Solitude's Reaver      113
# 591   4.07  Solitude's Reaver      113
# 764   4.07  Solitude's Reaver      113
# Name: (114, 'Yearning Mageblade')
#      Price           Item Name  Item ID
# 200   3.82  Yearning Mageblade      114
# 232   3.82  Yearning Mageblade      114
# 333   3.82  Yearning Mageblade      114
# 623   3.82  Yearning Mageblade      114
# 645   3.82  Yearning Mageblade      114
# Name: (115, 'Spectral Diamond Doomblade')
#      Price                   Item Name  Item ID
# 584   2.04  Spectral Diamond Doomblade      115
# 656   2.04  Spectral Diamond Doomblade      115
# Name: (116, 'Renewed Skeletal Katana')
#      Price                Item Name  Item ID
# 12    4.18  Renewed Skeletal Katana      116
# 38    4.18  Renewed Skeletal Katana      116
# 43    4.18  Renewed Skeletal Katana      116
# 646   4.18  Renewed Skeletal Katana      116
# Name: (117, 'Heartstriker, Legacy of the Light')
#      Price                          Item Name  Item ID
# 117   1.79  Heartstriker, Legacy of the Light      117
# 156   1.79  Heartstriker, Legacy of the Light      117
# 293   1.79  Heartstriker, Legacy of the Light      117
# 310   1.79  Heartstriker, Legacy of the Light      117
# 509   1.79  Heartstriker, Legacy of the Light      117
# 539   1.79  Heartstriker, Legacy of the Light      117
# 581   1.79  Heartstriker, Legacy of the Light      117
# Name: (118, 'Ghost Reaver, Longsword of Magic')
#      Price                         Item Name  Item ID
# 321   2.17  Ghost Reaver, Longsword of Magic      118
# Name: (119, 'Stormbringer, Dark Blade of Ending Misery')
#      Price                                  Item Name  Item ID
# 28    4.32  Stormbringer, Dark Blade of Ending Misery      119
# 264   4.32  Stormbringer, Dark Blade of Ending Misery      119
# 446   4.32  Stormbringer, Dark Blade of Ending Misery      119
# Name: (120, 'Agatha')
#      Price Item Name  Item ID
# 130   3.08    Agatha      120
# 211   3.08    Agatha      120
# 415   3.08    Agatha      120
# 432   3.08    Agatha      120
# 447   3.08    Agatha      120
# 670   3.08    Agatha      120
# Name: (121, 'Massacre')
#      Price Item Name  Item ID
# 346    1.6  Massacre      121
# 351    1.6  Massacre      121
# 543    1.6  Massacre      121
# 738    1.6  Massacre      121
# Name: (122, 'Unending Tyranny')
#      Price         Item Name  Item ID
# 451   2.85  Unending Tyranny      122
# 471   2.85  Unending Tyranny      122
# 672   2.85  Unending Tyranny      122
# Name: (123, "Twilight's Carver")
#      Price          Item Name  Item ID
# 169   2.28  Twilight's Carver      123
# 467   2.28  Twilight's Carver      123
# 568   2.28  Twilight's Carver      123
# 606   2.28  Twilight's Carver      123
# Name: (124, 'Venom Claymore')
#      Price       Item Name  Item ID
# 75    1.29  Venom Claymore      124
# 143   1.29  Venom Claymore      124
# 339   1.29  Venom Claymore      124
# 456   1.29  Venom Claymore      124
# Name: (125, 'Whistling Mithril Warblade')
#      Price                   Item Name  Item ID
# 63     1.0  Whistling Mithril Warblade      125
# 418    1.0  Whistling Mithril Warblade      125
# Name: (126, 'Exiled Mithril Longsword')
#      Price                 Item Name  Item ID
# 525    2.0  Exiled Mithril Longsword      126
# Name: (127, 'Heartseeker, Reaver of Souls')
#      Price                     Item Name  Item ID
# 642   3.92  Heartseeker, Reaver of Souls      127
# 740   3.92  Heartseeker, Reaver of Souls      127
# Name: (128, 'Blazeguard, Reach of Eternity')
#      Price                      Item Name  Item ID
# 284   4.91  Blazeguard, Reach of Eternity      128
# 388   4.91  Blazeguard, Reach of Eternity      128
# 517   4.91  Blazeguard, Reach of Eternity      128
# 577   4.91  Blazeguard, Reach of Eternity      128
# 593   4.91  Blazeguard, Reach of Eternity      128
# Name: (129, 'Fate, Vengeance of Eternal Justice')
#      Price                           Item Name  Item ID
# 86    1.54  Fate, Vengeance of Eternal Justice      129
# 386   1.54  Fate, Vengeance of Eternal Justice      129
# 402   1.54  Fate, Vengeance of Eternal Justice      129
# 420   1.54  Fate, Vengeance of Eternal Justice      129
# 459   1.54  Fate, Vengeance of Eternal Justice      129
# 622   1.54  Fate, Vengeance of Eternal Justice      129
# Name: (130, 'Alpha')
#      Price Item Name  Item ID
# 673   2.07     Alpha      130
# 699   2.07     Alpha      130
# 765   2.07     Alpha      130
# Name: (131, 'Fury')
#      Price Item Name  Item ID
# 4     1.44      Fury      131
# 323   1.44      Fury      131
# 396   1.44      Fury      131
# 407   1.44      Fury      131
# 574   1.44      Fury      131
# Name: (132, 'Persuasion')
#      Price   Item Name  Item ID
# 608   3.33  Persuasion      132
# 651   3.33  Persuasion      132
# Name: (133, "Faith's Scimitar")
#      Price         Item Name  Item ID
# 32    4.09  Faith's Scimitar      133
# 146   4.09  Faith's Scimitar      133
# 272   4.09  Faith's Scimitar      133
# 526   4.09  Faith's Scimitar      133
# 625   4.09  Faith's Scimitar      133
# Name: (134, 'Undead Crusader')
#     Price        Item Name  Item ID
# 97    4.5  Undead Crusader      134
# Name: (135, 'Warped Diamond Crusader')
#      Price                Item Name  Item ID
# 177    1.4  Warped Diamond Crusader      135
# 547    1.4  Warped Diamond Crusader      135
# 682    1.4  Warped Diamond Crusader      135
# Name: (136, 'Ghastly Adamantite Protector')
#      Price                     Item Name  Item ID
# 9     3.58  Ghastly Adamantite Protector      136
# 138   3.58  Ghastly Adamantite Protector      136
# 210   3.58  Ghastly Adamantite Protector      136
# 216   3.58  Ghastly Adamantite Protector      136
# 300   3.58  Ghastly Adamantite Protector      136
# 772   3.58  Ghastly Adamantite Protector      136
# Name: (137, 'Aetherius, Boon of the Blessed')
#      Price                       Item Name  Item ID
# 214   3.39  Aetherius, Boon of the Blessed      137
# 248   3.39  Aetherius, Boon of the Blessed      137
# 369   3.39  Aetherius, Boon of the Blessed      137
# 575   3.39  Aetherius, Boon of the Blessed      137
# 631   3.39  Aetherius, Boon of the Blessed      137
# Name: (138, 'Peacekeeper, Wit of Dark Magic')
#      Price                       Item Name  Item ID
# 48    4.74  Peacekeeper, Wit of Dark Magic      138
# 67    4.74  Peacekeeper, Wit of Dark Magic      138
# 199   4.74  Peacekeeper, Wit of Dark Magic      138
# 356   4.74  Peacekeeper, Wit of Dark Magic      138
# 367   4.74  Peacekeeper, Wit of Dark Magic      138
# Name: (139, 'Mercy, Katana of Dismay')
#      Price                Item Name  Item ID
# 110   4.94  Mercy, Katana of Dismay      139
# 116   4.94  Mercy, Katana of Dismay      139
# 231   4.94  Mercy, Katana of Dismay      139
# 246   4.94  Mercy, Katana of Dismay      139
# 493   4.94  Mercy, Katana of Dismay      139
# Name: (140, 'Striker')
#      Price Item Name  Item ID
# 30    2.94   Striker      140
# 113   2.94   Striker      140
# 355   2.94   Striker      140
# 519   2.94   Striker      140
# 659   2.94   Striker      140
# Name: (141, 'Persuasion')
#      Price   Item Name  Item ID
# 24    3.19  Persuasion      141
# 98    3.19  Persuasion      141
# 261   3.19  Persuasion      141
# 538   3.19  Persuasion      141
# 587   3.19  Persuasion      141
# 590   3.19  Persuasion      141
# 603   3.19  Persuasion      141
# Name: (142, 'Righteous Might')
#      Price        Item Name  Item ID
# 223   2.62  Righteous Might      142
# 529   2.62  Righteous Might      142
# 563   2.62  Righteous Might      142
# Name: (143, 'Frenzied Scimitar')
#      Price          Item Name  Item ID
# 1     1.56  Frenzied Scimitar      143
# 40    1.56  Frenzied Scimitar      143
# 70    1.56  Frenzied Scimitar      143
# 399   1.56  Frenzied Scimitar      143
# 492   1.56  Frenzied Scimitar      143
# 531   1.56  Frenzied Scimitar      143
# Name: (144, 'Blood Infused Guardian')
#      Price               Item Name  Item ID
# 174   1.94  Blood Infused Guardian      144
# 319   1.94  Blood Infused Guardian      144
# 409   1.94  Blood Infused Guardian      144
# 462   1.94  Blood Infused Guardian      144
# 675   1.94  Blood Infused Guardian      144
# 724   1.94  Blood Infused Guardian      144
# Name: (145, 'Fiery Glass Crusader')
#      Price             Item Name  Item ID
# 132   4.58  Fiery Glass Crusader      145
# 207   4.58  Fiery Glass Crusader      145
# 329   4.58  Fiery Glass Crusader      145
# 438   4.58  Fiery Glass Crusader      145
# 474   4.58  Fiery Glass Crusader      145
# 572   4.58  Fiery Glass Crusader      145
# 683   4.58  Fiery Glass Crusader      145
# 741   4.58  Fiery Glass Crusader      145
# 769   4.58  Fiery Glass Crusader      145
# Name: (146, 'Warped Iron Scimitar')
#      Price             Item Name  Item ID
# 135    3.1  Warped Iron Scimitar      146
# 534    3.1  Warped Iron Scimitar      146
# 549    3.1  Warped Iron Scimitar      146
# 596    3.1  Warped Iron Scimitar      146
# 747    3.1  Warped Iron Scimitar      146
# Name: (147, 'Hellreaver, Heirloom of Inception')
#      Price                          Item Name  Item ID
# 290   4.93  Hellreaver, Heirloom of Inception      147
# 312   4.93  Hellreaver, Heirloom of Inception      147
# 686   4.93  Hellreaver, Heirloom of Inception      147
# Name: (148, "Warmonger, Gift of Suffering's End")
#      Price                           Item Name  Item ID
# 148   4.03  Warmonger, Gift of Suffering's End      148
# 469   4.03  Warmonger, Gift of Suffering's End      148
# 490   4.03  Warmonger, Gift of Suffering's End      148
# Name: (149, 'Tranquility, Razor of Black Magic')
#      Price                          Item Name  Item ID
# 205   1.75  Tranquility, Razor of Black Magic      149
# 258   1.75  Tranquility, Razor of Black Magic      149
# 424   1.75  Tranquility, Razor of Black Magic      149
# 443   1.75  Tranquility, Razor of Black Magic      149
# 737   1.75  Tranquility, Razor of Black Magic      149
# Name: (150, 'Deathraze')
#      Price  Item Name  Item ID
# 114   2.85  Deathraze      150
# 124   2.85  Deathraze      150
# 185   2.85  Deathraze      150
# 445   2.85  Deathraze      150
# 648   2.85  Deathraze      150
# Name: (151, 'Severance')
#      Price  Item Name  Item ID
# 23     3.4  Severance      151
# 87     3.4  Severance      151
# 501    3.4  Severance      151
# Name: (152, 'Darkheart')
#      Price  Item Name  Item ID
# 58    1.74  Darkheart      152
# 328   1.74  Darkheart      152
# 395   1.74  Darkheart      152
# 671   1.74  Darkheart      152
# Name: (153, 'Mercenary Sabre')
#      Price        Item Name  Item ID
# 198   3.74  Mercenary Sabre      153
# 286   3.74  Mercenary Sabre      153
# 578   3.74  Mercenary Sabre      153
# 679   3.74  Mercenary Sabre      153
# Name: (154, 'Feral Katana')
#      Price     Item Name  Item ID
# 182    4.4  Feral Katana      154
# 225    4.4  Feral Katana      154
# 324    4.4  Feral Katana      154
# 422    4.4  Feral Katana      154
# Name: (155, 'War-Forged Gold Deflector')
#      Price                  Item Name  Item ID
# 282   1.01  War-Forged Gold Deflector      155
# 371   1.01  War-Forged Gold Deflector      155
# 535   1.01  War-Forged Gold Deflector      155
# 552   1.01  War-Forged Gold Deflector      155
# 586   1.01  War-Forged Gold Deflector      155
# Name: (156, 'Soul-Forged Steel Shortsword')
#      Price                     Item Name  Item ID
# 288   1.77  Soul-Forged Steel Shortsword      156
# 433   1.77  Soul-Forged Steel Shortsword      156
# 441   1.77  Soul-Forged Steel Shortsword      156
# 573   1.77  Soul-Forged Steel Shortsword      156
# 721   1.77  Soul-Forged Steel Shortsword      156
# Name: (157, 'Spada, Etcher of Hatred')
#      Price                Item Name  Item ID
# 167    4.8  Spada, Etcher of Hatred      157
# 176    4.8  Spada, Etcher of Hatred      157
# 224    4.8  Spada, Etcher of Hatred      157
# 389    4.8  Spada, Etcher of Hatred      157
# Name: (158, 'Darkheart, Butcher of the Champion')
#      Price                           Item Name  Item ID
# 139   2.45  Darkheart, Butcher of the Champion      158
# 719   2.45  Darkheart, Butcher of the Champion      158
# Name: (159, 'Oathbreaker, Spellblade of Trials')
#      Price                          Item Name  Item ID
# 212   3.08  Oathbreaker, Spellblade of Trials      159
# 546   3.08  Oathbreaker, Spellblade of Trials      159
# 605   3.08  Oathbreaker, Spellblade of Trials      159
# 610   3.08  Oathbreaker, Spellblade of Trials      159
# 613   3.08  Oathbreaker, Spellblade of Trials      159
# 720   3.08  Oathbreaker, Spellblade of Trials      159
# 746   3.08  Oathbreaker, Spellblade of Trials      159
# Name: (160, 'Azurewrath')
#      Price   Item Name  Item ID
# 34     4.4  Azurewrath      160
# 82     4.4  Azurewrath      160
# 518    4.4  Azurewrath      160
# 551    4.4  Azurewrath      160
# 632    4.4  Azurewrath      160
# 703    4.4  Azurewrath      160
# Name: (161, 'Devine')
#      Price Item Name  Item ID
# 17    1.76    Devine      161
# 149   1.76    Devine      161
# 332   1.76    Devine      161
# 541   1.76    Devine      161
# 650   1.76    Devine      161
# Name: (162, 'Abyssal Shard')
#      Price      Item Name  Item ID
# 7     2.67  Abyssal Shard      162
# 11    2.67  Abyssal Shard      162
# 209   2.67  Abyssal Shard      162
# 403   2.67  Abyssal Shard      162
# 510   2.67  Abyssal Shard      162
# Name: (163, 'Thunderfury Scimitar')
#      Price             Item Name  Item ID
# 235   3.45  Thunderfury Scimitar      163
# 279   3.45  Thunderfury Scimitar      163
# 285   3.45  Thunderfury Scimitar      163
# 354   3.45  Thunderfury Scimitar      163
# 637   3.45  Thunderfury Scimitar      163
# Name: (164, 'Exiled Doomblade')
#      Price         Item Name  Item ID
# 95    1.63  Exiled Doomblade      164
# 153   1.63  Exiled Doomblade      164
# 299   1.63  Exiled Doomblade      164
# 382   1.63  Exiled Doomblade      164
# 430   1.63  Exiled Doomblade      164
# 694   1.63  Exiled Doomblade      164
# 776   1.63  Exiled Doomblade      164
# Name: (165, 'Bone Crushing Silver Skewer')
#      Price                    Item Name  Item ID
# 14    4.86  Bone Crushing Silver Skewer      165
# 80    4.86  Bone Crushing Silver Skewer      165
# 571   4.86  Bone Crushing Silver Skewer      165
# 734   4.86  Bone Crushing Silver Skewer      165
# Name: (166, 'Thirsty Iron Reaver')
#      Price            Item Name  Item ID
# 271   3.07  Thirsty Iron Reaver      166
# 458   3.07  Thirsty Iron Reaver      166
# 600   3.07  Thirsty Iron Reaver      166
# Name: (167, 'Malice, Legacy of the Queen')
#      Price                    Item Name  Item ID
# 278   3.61  Malice, Legacy of the Queen      167
# 330   3.61  Malice, Legacy of the Queen      167
# 628   3.61  Malice, Legacy of the Queen      167
# 750   3.61  Malice, Legacy of the Queen      167
# Name: (168, 'Sun Strike, Jaws of Twisted Visions')
#      Price                            Item Name  Item ID
# 21    1.48  Sun Strike, Jaws of Twisted Visions      168
# 461   1.48  Sun Strike, Jaws of Twisted Visions      168
# Name: (169, 'Interrogator, Blood Blade of the Queen')
#      Price                               Item Name  Item ID
# 6     2.18  Interrogator, Blood Blade of the Queen      169
# 297   2.18  Interrogator, Blood Blade of the Queen      169
# 512   2.18  Interrogator, Blood Blade of the Queen      169
# 684   2.18  Interrogator, Blood Blade of the Queen      169
# Name: (170, 'Shadowsteel')
#      Price    Item Name  Item ID
# 47    3.97  Shadowsteel      170
# 309   3.97  Shadowsteel      170
# 427   3.97  Shadowsteel      170
# 592   3.97  Shadowsteel      170
# Name: (171, 'Scalpel')
#      Price Item Name  Item ID
# 294   1.79   Scalpel      171
# 419   1.79   Scalpel      171
# 630   1.79   Scalpel      171
# Name: (172, 'Blade of the Grave')
#      Price           Item Name  Item ID
# 39    3.14  Blade of the Grave      172
# 262   3.14  Blade of the Grave      172
# 265   3.14  Blade of the Grave      172
# 431   3.14  Blade of the Grave      172
# Name: (173, 'Stormfury Longsword')
#      Price            Item Name  Item ID
# 275   4.93  Stormfury Longsword      173
# 477   4.93  Stormfury Longsword      173
# Name: (174, 'Primitive Blade')
#      Price        Item Name  Item ID
# 81    3.47  Primitive Blade      174
# 101   3.47  Primitive Blade      174
# 122   3.47  Primitive Blade      174
# 353   3.47  Primitive Blade      174
# Name: (175, 'Woeful Adamantite Claymore')
#      Price                   Item Name  Item ID
# 142   4.48  Woeful Adamantite Claymore      175
# 221   4.48  Woeful Adamantite Claymore      175
# 257   4.48  Woeful Adamantite Claymore      175
# Name: (176, 'Relentless Iron Skewer')
#      Price               Item Name  Item ID
# 53    2.84  Relentless Iron Skewer      176
# 611   2.84  Relentless Iron Skewer      176
# Name: (177, 'Winterthorn, Defender of Shifting Worlds')
#      Price                                 Item Name  Item ID
# 717   2.08  Winterthorn, Defender of Shifting Worlds      177
# 723   2.08  Winterthorn, Defender of Shifting Worlds      177
# Name: (178, 'Oathbreaker, Last Hope of the Breaking Storm')
#      Price                                     Item Name  Item ID
# 25    4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 61    4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 62    4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 72    4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 222   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 464   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 580   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 627   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 658   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 706   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 730   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# 753   4.23  Oathbreaker, Last Hope of the Breaking Storm      178
# Name: (179, 'Wolf, Promise of the Moonwalker')
#      Price                        Item Name  Item ID
# 31    4.48  Wolf, Promise of the Moonwalker      179
# 137   4.48  Wolf, Promise of the Moonwalker      179
# 305   4.48  Wolf, Promise of the Moonwalker      179
# 429   4.48  Wolf, Promise of the Moonwalker      179
# 481   4.48  Wolf, Promise of the Moonwalker      179
# 565   4.48  Wolf, Promise of the Moonwalker      179
# Name: (180, 'Stormcaller')
#      Price    Item Name  Item ID
# 751   3.36  Stormcaller      180
# Name: (181, "Reaper's Toll")
#      Price      Item Name  Item ID
# 45    1.66  Reaper's Toll      181
# 162   1.66  Reaper's Toll      181
# 304   1.66  Reaper's Toll      181
# 375   1.66  Reaper's Toll      181
# 392   1.66  Reaper's Toll      181
# Name: (182, 'Toothpick')
#      Price  Item Name  Item ID
# 256   4.03  Toothpick      182
# 313   4.03  Toothpick      182
# 758   4.03  Toothpick      182
# Name: (183, "Dragon's Greatsword")
#      Price            Item Name  Item ID
# 165   1.09  Dragon's Greatsword      183
# 618   1.09  Dragon's Greatsword      183
# 705   1.09  Dragon's Greatsword      183

# %%
items_gb = items_df.groupby(["Item ID", "Item Name"])

total_purch_value = items_gb.sum()["Price"]
total_purch_count = items_gb.count()["Price"]
total_purch_value = items_gb.mean()["Price"]

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame
